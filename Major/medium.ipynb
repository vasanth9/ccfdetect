# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanth9/ccfdetect/blob/master/Major/medium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### SETUP

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
# %matplotlib inline
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 14, 8
RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %% [markdown]
# ### LOADING THE DATA

# %%
df = pd.read_csv("/content/drive/MyDrive/creditcard.csv")

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().values.any()
# Out:
# False

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
frauds.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# ### PREPARING THE DATA

# %%
from sklearn.preprocessing import StandardScaler
data = df.drop(['Time'], axis=1)
data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)
y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)
X_train = X_train.values
X_test = X_test.values
X_train.shape
# Out:
# (227451, 29)

# %% [markdown]
# ### BUILDING THE MODEL

# %%
input_dim = X_train.shape[1]
encoding_dim = 14
input_layer = Input(shape=(input_dim, ))
encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)
decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
nb_epoch = 100
batch_size = 32
autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.8570 - accuracy: 0.5136 - val_loss: 0.7872 - val_accuracy: 0.6594
# Epoch 2/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7530 - accuracy: 0.6637 - val_loss: 0.7664 - val_accuracy: 0.6614
# Epoch 3/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7452 - accuracy: 0.6726 - val_loss: 0.7551 - val_accuracy: 0.6790
# Epoch 4/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7248 - accuracy: 0.6799 - val_loss: 0.7517 - val_accuracy: 0.6861
# Epoch 5/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7228 - accuracy: 0.6834 - val_loss: 0.7499 - val_accuracy: 0.6891
# Epoch 6/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7202 - accuracy: 0.6908 - val_loss: 0.7491 - val_accuracy: 0.6840
# Epoch 7/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7017 - accuracy: 0.6903 - val_loss: 0.7474 - val_accuracy: 0.6934
# Epoch 8/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7312 - accuracy: 0.6894 - val_loss: 0.7472 - val_accuracy: 0.6926
# Epoch 9/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7235 - accuracy: 0.6924 - val_loss: 0.7450 - val_accuracy: 0.6960
# Epoch 10/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7006 - accuracy: 0.6961 - val_loss: 0.7447 - val_accuracy: 0.6953
# Epoch 11/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7125 - accuracy: 0.6956 - val_loss: 0.7423 - val_accuracy: 0.6925
# Epoch 12/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7182 - accuracy: 0.6954 - val_loss: 0.7408 - val_accuracy: 0.7019
# Epoch 13/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7069 - accuracy: 0.6972 - val_loss: 0.7406 - val_accuracy: 0.6965
# Epoch 14/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7131 - accuracy: 0.6961 - val_loss: 0.7399 - val_accuracy: 0.7007
# Epoch 15/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7142 - accuracy: 0.6962 - val_loss: 0.7394 - val_accuracy: 0.7019
# Epoch 16/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7017 - accuracy: 0.6978 - val_loss: 0.7399 - val_accuracy: 0.6983
# Epoch 17/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7022 - accuracy: 0.6988 - val_loss: 0.7400 - val_accuracy: 0.6998
# Epoch 18/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7184 - accuracy: 0.6981 - val_loss: 0.7432 - val_accuracy: 0.6871
# Epoch 19/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7027 - accuracy: 0.6977 - val_loss: 0.7384 - val_accuracy: 0.6979
# Epoch 20/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6979 - accuracy: 0.6997 - val_loss: 0.7405 - val_accuracy: 0.6899
# Epoch 21/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7080 - accuracy: 0.6964 - val_loss: 0.7377 - val_accuracy: 0.7029
# Epoch 22/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7006 - accuracy: 0.6969 - val_loss: 0.7381 - val_accuracy: 0.7021
# Epoch 23/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7119 - accuracy: 0.6988 - val_loss: 0.7396 - val_accuracy: 0.6929
# Epoch 24/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7013 - accuracy: 0.6999 - val_loss: 0.7385 - val_accuracy: 0.7005
# Epoch 25/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6949 - accuracy: 0.7040 - val_loss: 0.7368 - val_accuracy: 0.7091
# Epoch 26/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7051 - accuracy: 0.7160 - val_loss: 0.7350 - val_accuracy: 0.7141
# Epoch 27/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6980 - accuracy: 0.7161 - val_loss: 0.7376 - val_accuracy: 0.7197
# Epoch 28/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7174 - accuracy: 0.7185 - val_loss: 0.7355 - val_accuracy: 0.7122
# Epoch 29/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6955 - accuracy: 0.7204 - val_loss: 0.7328 - val_accuracy: 0.7165
# Epoch 30/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6921 - accuracy: 0.7228 - val_loss: 0.7328 - val_accuracy: 0.7138
# Epoch 31/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7071 - accuracy: 0.7230 - val_loss: 0.7313 - val_accuracy: 0.7259
# Epoch 32/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7060 - accuracy: 0.7243 - val_loss: 0.7327 - val_accuracy: 0.7300
# Epoch 33/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6958 - accuracy: 0.7260 - val_loss: 0.7318 - val_accuracy: 0.7274
# Epoch 34/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6979 - accuracy: 0.7270 - val_loss: 0.7336 - val_accuracy: 0.7225
# Epoch 35/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6978 - accuracy: 0.7262 - val_loss: 0.7315 - val_accuracy: 0.7243
# Epoch 36/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7056 - accuracy: 0.7259 - val_loss: 0.7330 - val_accuracy: 0.7211
# Epoch 37/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6895 - accuracy: 0.7278 - val_loss: 0.7328 - val_accuracy: 0.7209
# Epoch 38/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7099 - accuracy: 0.7273 - val_loss: 0.7312 - val_accuracy: 0.7271
# Epoch 39/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7118 - accuracy: 0.7275 - val_loss: 0.7315 - val_accuracy: 0.7270
# Epoch 40/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6918 - accuracy: 0.7285 - val_loss: 0.7320 - val_accuracy: 0.7255
# Epoch 41/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6961 - accuracy: 0.7266 - val_loss: 0.7319 - val_accuracy: 0.7296
# Epoch 42/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7019 - accuracy: 0.7271 - val_loss: 0.7306 - val_accuracy: 0.7300
# Epoch 43/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6885 - accuracy: 0.7294 - val_loss: 0.7311 - val_accuracy: 0.7279
# Epoch 44/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7042 - accuracy: 0.7282 - val_loss: 0.7324 - val_accuracy: 0.7236
# Epoch 45/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6949 - accuracy: 0.7284 - val_loss: 0.7302 - val_accuracy: 0.7324
# Epoch 46/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.7103 - accuracy: 0.7288 - val_loss: 0.7320 - val_accuracy: 0.7273
# Epoch 47/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6842 - accuracy: 0.7301 - val_loss: 0.7321 - val_accuracy: 0.7283
# Epoch 48/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6872 - accuracy: 0.7284 - val_loss: 0.7301 - val_accuracy: 0.7300
# Epoch 49/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6912 - accuracy: 0.7285 - val_loss: 0.7312 - val_accuracy: 0.7182
# Epoch 50/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7002 - accuracy: 0.7299 - val_loss: 0.7307 - val_accuracy: 0.7287
# Epoch 51/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6790 - accuracy: 0.7289 - val_loss: 0.7308 - val_accuracy: 0.7309
# Epoch 52/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6827 - accuracy: 0.7310 - val_loss: 0.7312 - val_accuracy: 0.7220
# Epoch 53/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7146 - accuracy: 0.7274 - val_loss: 0.7306 - val_accuracy: 0.7211
# Epoch 54/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6962 - accuracy: 0.7272 - val_loss: 0.7292 - val_accuracy: 0.7346
# Epoch 55/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6865 - accuracy: 0.7285 - val_loss: 0.7301 - val_accuracy: 0.7247
# Epoch 56/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6903 - accuracy: 0.7289 - val_loss: 0.7314 - val_accuracy: 0.7182
# Epoch 57/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6903 - accuracy: 0.7312 - val_loss: 0.7296 - val_accuracy: 0.7285
# Epoch 58/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6794 - accuracy: 0.7297 - val_loss: 0.7321 - val_accuracy: 0.7282
# Epoch 59/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6885 - accuracy: 0.7309 - val_loss: 0.7306 - val_accuracy: 0.7323
# Epoch 60/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7233 - accuracy: 0.7307 - val_loss: 0.7284 - val_accuracy: 0.7304
# Epoch 61/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6949 - accuracy: 0.7310 - val_loss: 0.7305 - val_accuracy: 0.7263
# Epoch 62/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6901 - accuracy: 0.7303 - val_loss: 0.7296 - val_accuracy: 0.7309
# Epoch 63/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6862 - accuracy: 0.7308 - val_loss: 0.7293 - val_accuracy: 0.7295
# Epoch 64/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7014 - accuracy: 0.7316 - val_loss: 0.7345 - val_accuracy: 0.7179
# Epoch 65/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6909 - accuracy: 0.7299 - val_loss: 0.7306 - val_accuracy: 0.7318
# Epoch 66/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6916 - accuracy: 0.7324 - val_loss: 0.7280 - val_accuracy: 0.7361
# Epoch 67/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7011 - accuracy: 0.7325 - val_loss: 0.7291 - val_accuracy: 0.7299
# Epoch 68/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6858 - accuracy: 0.7320 - val_loss: 0.7295 - val_accuracy: 0.7309
# Epoch 69/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6968 - accuracy: 0.7324 - val_loss: 0.7298 - val_accuracy: 0.7234
# Epoch 70/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7020 - accuracy: 0.7324 - val_loss: 0.7291 - val_accuracy: 0.7382
# Epoch 71/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6903 - accuracy: 0.7334 - val_loss: 0.7296 - val_accuracy: 0.7284
# Epoch 72/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6937 - accuracy: 0.7348 - val_loss: 0.7289 - val_accuracy: 0.7313
# Epoch 73/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6925 - accuracy: 0.7318 - val_loss: 0.7281 - val_accuracy: 0.7350
# Epoch 74/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6949 - accuracy: 0.7342 - val_loss: 0.7282 - val_accuracy: 0.7352
# Epoch 75/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6815 - accuracy: 0.7348 - val_loss: 0.7309 - val_accuracy: 0.7272
# Epoch 76/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7045 - accuracy: 0.7344 - val_loss: 0.7276 - val_accuracy: 0.7350
# Epoch 77/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6951 - accuracy: 0.7340 - val_loss: 0.7262 - val_accuracy: 0.7371
# Epoch 78/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7143 - accuracy: 0.7338 - val_loss: 0.7265 - val_accuracy: 0.7374
# Epoch 79/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6967 - accuracy: 0.7342 - val_loss: 0.7267 - val_accuracy: 0.7375
# Epoch 80/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7088 - accuracy: 0.7322 - val_loss: 0.7258 - val_accuracy: 0.7394
# Epoch 81/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7158 - accuracy: 0.7325 - val_loss: 0.7255 - val_accuracy: 0.7386
# Epoch 82/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6835 - accuracy: 0.7366 - val_loss: 0.7274 - val_accuracy: 0.7372
# Epoch 83/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6945 - accuracy: 0.7350 - val_loss: 0.7272 - val_accuracy: 0.7349
# Epoch 84/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6880 - accuracy: 0.7352 - val_loss: 0.7297 - val_accuracy: 0.7346
# Epoch 85/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7038 - accuracy: 0.7354 - val_loss: 0.7259 - val_accuracy: 0.7330
# Epoch 86/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6916 - accuracy: 0.7359 - val_loss: 0.7284 - val_accuracy: 0.7318
# Epoch 87/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6888 - accuracy: 0.7360 - val_loss: 0.7255 - val_accuracy: 0.7343
# Epoch 88/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6905 - accuracy: 0.7375 - val_loss: 0.7257 - val_accuracy: 0.7382
# Epoch 89/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6851 - accuracy: 0.7349 - val_loss: 0.7252 - val_accuracy: 0.7282
# Epoch 90/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6905 - accuracy: 0.7360 - val_loss: 0.7257 - val_accuracy: 0.7410
# Epoch 91/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6841 - accuracy: 0.7361 - val_loss: 0.7276 - val_accuracy: 0.7315
# Epoch 92/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6874 - accuracy: 0.7359 - val_loss: 0.7254 - val_accuracy: 0.7329
# Epoch 93/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6953 - accuracy: 0.7366 - val_loss: 0.7265 - val_accuracy: 0.7335
# Epoch 94/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6809 - accuracy: 0.7363 - val_loss: 0.7269 - val_accuracy: 0.7283
# Epoch 95/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6825 - accuracy: 0.7355 - val_loss: 0.7268 - val_accuracy: 0.7234
# Epoch 96/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6851 - accuracy: 0.7363 - val_loss: 0.7302 - val_accuracy: 0.7229
# Epoch 97/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.6880 - accuracy: 0.7345 - val_loss: 0.7255 - val_accuracy: 0.7362
# Epoch 98/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6909 - accuracy: 0.7358 - val_loss: 0.7250 - val_accuracy: 0.7353
# Epoch 99/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6990 - accuracy: 0.7354 - val_loss: 0.7253 - val_accuracy: 0.7324
# Epoch 100/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.6918 - accuracy: 0.7349 - val_loss: 0.7271 - val_accuracy: 0.7215

# %%
autoencoder = load_model('model.h5')

# %% [markdown]
# ### EVALUATION

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.724095      0.001720
# std                3.336952      0.041443
# min                0.046012      0.000000
# 25%                0.228007      0.000000
# 50%                0.376760      0.000000
# 75%                0.604240      0.000000
# max              250.790227      1.000000

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %% [markdown]
# ### PREDICTION

# %%
threshold = 2.9

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
