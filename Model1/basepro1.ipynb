# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanth9/ccfdetect/blob/master/Model1/basepro1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from io import StringIO

# %%
df = pd.read_csv('/content/drive/MyDrive/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %%
# %matplotlib inline
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 14, 8
RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.isnull().values.any()
# Out:
# False

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]
frauds.shape
# Out:
# (492, 31)

# %%
normal.shape
# Out:
# (284315, 31)

# %%
frauds.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
data = df.drop(['Time'], axis=1)
data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)
y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)
X_train = X_train.values
X_test = X_test.values
X_train.shape
# Out:
# (227451, 29)

# %%
input_dim = X_train.shape[1]
encoding_dim = 14
input_layer = Input(shape=(input_dim, ))
encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)
decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
nb_epoch = 100
batch_size = 32
autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 7108/7108 [==============================] - 13s 2ms/step - loss: 0.8852 - accuracy: 0.4845 - val_loss: 0.8178 - val_accuracy: 0.6241
# Epoch 2/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7925 - accuracy: 0.6349 - val_loss: 0.7942 - val_accuracy: 0.6351
# Epoch 3/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7896 - accuracy: 0.6475 - val_loss: 0.7836 - val_accuracy: 0.6661
# Epoch 4/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7783 - accuracy: 0.6679 - val_loss: 0.7786 - val_accuracy: 0.6723
# Epoch 5/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7495 - accuracy: 0.6776 - val_loss: 0.7749 - val_accuracy: 0.6785
# Epoch 6/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7408 - accuracy: 0.6865 - val_loss: 0.7711 - val_accuracy: 0.6933
# Epoch 7/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7459 - accuracy: 0.6899 - val_loss: 0.7669 - val_accuracy: 0.6926
# Epoch 8/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7191 - accuracy: 0.6944 - val_loss: 0.7667 - val_accuracy: 0.6920
# Epoch 9/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7356 - accuracy: 0.6983 - val_loss: 0.7641 - val_accuracy: 0.7020
# Epoch 10/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7417 - accuracy: 0.6976 - val_loss: 0.7654 - val_accuracy: 0.6935
# Epoch 11/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7438 - accuracy: 0.6996 - val_loss: 0.7627 - val_accuracy: 0.6971
# Epoch 12/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7320 - accuracy: 0.7000 - val_loss: 0.7637 - val_accuracy: 0.7033
# Epoch 13/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7402 - accuracy: 0.6981 - val_loss: 0.7627 - val_accuracy: 0.6973
# Epoch 14/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7324 - accuracy: 0.7006 - val_loss: 0.7616 - val_accuracy: 0.7004
# Epoch 15/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7291 - accuracy: 0.6969 - val_loss: 0.7624 - val_accuracy: 0.6969
# Epoch 16/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7245 - accuracy: 0.6995 - val_loss: 0.7620 - val_accuracy: 0.7026
# Epoch 17/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7265 - accuracy: 0.7006 - val_loss: 0.7631 - val_accuracy: 0.6943
# Epoch 18/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7276 - accuracy: 0.7011 - val_loss: 0.7615 - val_accuracy: 0.6950
# Epoch 19/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7302 - accuracy: 0.7009 - val_loss: 0.7604 - val_accuracy: 0.7012
# Epoch 20/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7250 - accuracy: 0.7012 - val_loss: 0.7623 - val_accuracy: 0.6951
# Epoch 21/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7214 - accuracy: 0.7005 - val_loss: 0.7640 - val_accuracy: 0.6884
# Epoch 22/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7242 - accuracy: 0.7013 - val_loss: 0.7607 - val_accuracy: 0.6938
# Epoch 23/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7521 - accuracy: 0.6995 - val_loss: 0.7602 - val_accuracy: 0.6982
# Epoch 24/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7318 - accuracy: 0.7004 - val_loss: 0.7605 - val_accuracy: 0.7020
# Epoch 25/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7695 - accuracy: 0.7003 - val_loss: 0.7600 - val_accuracy: 0.6962
# Epoch 26/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7435 - accuracy: 0.6999 - val_loss: 0.7607 - val_accuracy: 0.7010
# Epoch 27/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7232 - accuracy: 0.7011 - val_loss: 0.7602 - val_accuracy: 0.6946
# Epoch 28/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7283 - accuracy: 0.6998 - val_loss: 0.7606 - val_accuracy: 0.7042
# Epoch 29/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7498 - accuracy: 0.7016 - val_loss: 0.7601 - val_accuracy: 0.7062
# Epoch 30/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7302 - accuracy: 0.7033 - val_loss: 0.7601 - val_accuracy: 0.7007
# Epoch 31/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7228 - accuracy: 0.7009 - val_loss: 0.7609 - val_accuracy: 0.7052
# Epoch 32/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7226 - accuracy: 0.7011 - val_loss: 0.7587 - val_accuracy: 0.7010
# Epoch 33/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7259 - accuracy: 0.7015 - val_loss: 0.7601 - val_accuracy: 0.6943
# Epoch 34/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7542 - accuracy: 0.7014 - val_loss: 0.7602 - val_accuracy: 0.7025
# Epoch 35/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7268 - accuracy: 0.7029 - val_loss: 0.7605 - val_accuracy: 0.6974
# Epoch 36/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7384 - accuracy: 0.7023 - val_loss: 0.7590 - val_accuracy: 0.7022
# Epoch 37/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7296 - accuracy: 0.7016 - val_loss: 0.7600 - val_accuracy: 0.7037
# Epoch 38/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7367 - accuracy: 0.7051 - val_loss: 0.7589 - val_accuracy: 0.7042
# Epoch 39/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7392 - accuracy: 0.7045 - val_loss: 0.7595 - val_accuracy: 0.6996
# Epoch 40/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7161 - accuracy: 0.7034 - val_loss: 0.7599 - val_accuracy: 0.7082
# Epoch 41/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7209 - accuracy: 0.7031 - val_loss: 0.7609 - val_accuracy: 0.7018
# Epoch 42/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7214 - accuracy: 0.7027 - val_loss: 0.7596 - val_accuracy: 0.6983
# Epoch 43/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7318 - accuracy: 0.7021 - val_loss: 0.7589 - val_accuracy: 0.6999
# Epoch 44/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7151 - accuracy: 0.7027 - val_loss: 0.7598 - val_accuracy: 0.6959
# Epoch 45/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7424 - accuracy: 0.7027 - val_loss: 0.7595 - val_accuracy: 0.6953
# Epoch 46/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7357 - accuracy: 0.7012 - val_loss: 0.7577 - val_accuracy: 0.7066
# Epoch 47/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7017 - accuracy: 0.7049 - val_loss: 0.7600 - val_accuracy: 0.7025
# Epoch 48/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7300 - accuracy: 0.7007 - val_loss: 0.7597 - val_accuracy: 0.7029
# Epoch 49/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7434 - accuracy: 0.7012 - val_loss: 0.7582 - val_accuracy: 0.7032
# Epoch 50/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7272 - accuracy: 0.7034 - val_loss: 0.7579 - val_accuracy: 0.7029
# Epoch 51/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7345 - accuracy: 0.7038 - val_loss: 0.7586 - val_accuracy: 0.7058
# Epoch 52/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7276 - accuracy: 0.7024 - val_loss: 0.7586 - val_accuracy: 0.7046
# Epoch 53/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7200 - accuracy: 0.7038 - val_loss: 0.7577 - val_accuracy: 0.7030
# Epoch 54/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7454 - accuracy: 0.7038 - val_loss: 0.7615 - val_accuracy: 0.6957
# Epoch 55/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7260 - accuracy: 0.7021 - val_loss: 0.7605 - val_accuracy: 0.7076
# Epoch 56/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7204 - accuracy: 0.7041 - val_loss: 0.7576 - val_accuracy: 0.7083
# Epoch 57/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7490 - accuracy: 0.7030 - val_loss: 0.7581 - val_accuracy: 0.7040
# Epoch 58/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7465 - accuracy: 0.7031 - val_loss: 0.7576 - val_accuracy: 0.7058
# Epoch 59/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7156 - accuracy: 0.7044 - val_loss: 0.7593 - val_accuracy: 0.7003
# Epoch 60/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7417 - accuracy: 0.7018 - val_loss: 0.7578 - val_accuracy: 0.7081
# Epoch 61/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7091 - accuracy: 0.7044 - val_loss: 0.7579 - val_accuracy: 0.7113
# Epoch 62/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7306 - accuracy: 0.7029 - val_loss: 0.7588 - val_accuracy: 0.7050
# Epoch 63/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7541 - accuracy: 0.7028 - val_loss: 0.7599 - val_accuracy: 0.6957
# Epoch 64/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7247 - accuracy: 0.7044 - val_loss: 0.7579 - val_accuracy: 0.7037
# Epoch 65/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7187 - accuracy: 0.7050 - val_loss: 0.7576 - val_accuracy: 0.7077
# Epoch 66/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7244 - accuracy: 0.7044 - val_loss: 0.7582 - val_accuracy: 0.7074
# Epoch 67/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7353 - accuracy: 0.7027 - val_loss: 0.7580 - val_accuracy: 0.7036
# Epoch 68/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7446 - accuracy: 0.7034 - val_loss: 0.7638 - val_accuracy: 0.6990
# Epoch 69/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7348 - accuracy: 0.7027 - val_loss: 0.7602 - val_accuracy: 0.6943
# Epoch 70/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7188 - accuracy: 0.7052 - val_loss: 0.7577 - val_accuracy: 0.7096
# Epoch 71/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7217 - accuracy: 0.7025 - val_loss: 0.7574 - val_accuracy: 0.7068
# Epoch 72/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7302 - accuracy: 0.7035 - val_loss: 0.7591 - val_accuracy: 0.6968
# Epoch 73/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7329 - accuracy: 0.7052 - val_loss: 0.7589 - val_accuracy: 0.7003
# Epoch 74/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7373 - accuracy: 0.7038 - val_loss: 0.7573 - val_accuracy: 0.7091
# Epoch 75/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7188 - accuracy: 0.7043 - val_loss: 0.7587 - val_accuracy: 0.6991
# Epoch 76/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7245 - accuracy: 0.7058 - val_loss: 0.7577 - val_accuracy: 0.7009
# Epoch 77/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7348 - accuracy: 0.7062 - val_loss: 0.7634 - val_accuracy: 0.6936
# Epoch 78/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7467 - accuracy: 0.7039 - val_loss: 0.7580 - val_accuracy: 0.6992
# Epoch 79/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7326 - accuracy: 0.7037 - val_loss: 0.7582 - val_accuracy: 0.7055
# Epoch 80/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7668 - accuracy: 0.7036 - val_loss: 0.7574 - val_accuracy: 0.7029
# Epoch 81/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7154 - accuracy: 0.7063 - val_loss: 0.7579 - val_accuracy: 0.7058
# Epoch 82/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7325 - accuracy: 0.7049 - val_loss: 0.7577 - val_accuracy: 0.7027
# Epoch 83/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7318 - accuracy: 0.7042 - val_loss: 0.7583 - val_accuracy: 0.7079
# Epoch 84/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7215 - accuracy: 0.7046 - val_loss: 0.7583 - val_accuracy: 0.7058
# Epoch 85/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7241 - accuracy: 0.7016 - val_loss: 0.7573 - val_accuracy: 0.7062
# Epoch 86/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7375 - accuracy: 0.7021 - val_loss: 0.7585 - val_accuracy: 0.7043
# Epoch 87/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7554 - accuracy: 0.7048 - val_loss: 0.7575 - val_accuracy: 0.7038
# Epoch 88/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7274 - accuracy: 0.7030 - val_loss: 0.7587 - val_accuracy: 0.6991
# Epoch 89/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7327 - accuracy: 0.7058 - val_loss: 0.7571 - val_accuracy: 0.7108
# Epoch 90/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7161 - accuracy: 0.7066 - val_loss: 0.7588 - val_accuracy: 0.7017
# Epoch 91/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7281 - accuracy: 0.7051 - val_loss: 0.7575 - val_accuracy: 0.7027
# Epoch 92/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7389 - accuracy: 0.7049 - val_loss: 0.7587 - val_accuracy: 0.7007
# Epoch 93/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7294 - accuracy: 0.7040 - val_loss: 0.7587 - val_accuracy: 0.7016
# Epoch 94/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7284 - accuracy: 0.7054 - val_loss: 0.7579 - val_accuracy: 0.7063
# Epoch 95/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7336 - accuracy: 0.7048 - val_loss: 0.7584 - val_accuracy: 0.7053
# Epoch 96/100
# 7108/7108 [==============================] - 11s 2ms/step - loss: 0.7248 - accuracy: 0.7049 - val_loss: 0.7567 - val_accuracy: 0.7094
# Epoch 97/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7315 - accuracy: 0.7051 - val_loss: 0.7580 - val_accuracy: 0.6991
# Epoch 98/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7225 - accuracy: 0.7046 - val_loss: 0.7571 - val_accuracy: 0.6993
# Epoch 99/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7265 - accuracy: 0.7046 - val_loss: 0.7606 - val_accuracy: 0.6989
# Epoch 100/100
# 7108/7108 [==============================] - 12s 2ms/step - loss: 0.7375 - accuracy: 0.7060 - val_loss: 0.7567 - val_accuracy: 0.7079

# %%
autoencoder = load_model('model.h5')

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.755717      0.001720
# std                3.467072      0.041443
# min                0.042855      0.000000
# 25%                0.240323      0.000000
# 50%                0.381512      0.000000
# 75%                0.609379      0.000000
# max              257.204127      1.000000

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %%
threshold = 2.9

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)
plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
